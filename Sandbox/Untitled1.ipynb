# %%
import pandas as pd

pd.set_option('display.max_rows', 1000)

# %%
filename = 'ca-500.csv'

# %%
df = pd.read_csv(filename, sep=';')

# %%
df[['first_name','last_name','city']]
# Out:
#       first_name      last_name                      city
# 0      Francoise  Rautenstrauch                   Windsor
# 1         Kendra           Loud                    Alcida
# 2        Lourdes       Bauswell                Belleville
# 3         Hannah        Edmison                 Vancouver
# 4            Tom          Loeza               LIle-Perrot
# 5        Queenie     Kramarczyk             Swift Current
# 6            Hui        Portaro               Baker Brook
# 7         Josefa          Opitz                     Delhi
# 8            Lea      Steinhaus                  Bradford
# 9          Paola         Vielma                    Aurora
# 10     Hortencia        Bresser             New Waterford
# 11        Leanna       Tijerina                North York
# 12        Danilo          Pride                  Red Deer
# 13          Huey       Marcille                  Edmonton
# 14      Apolonia          Warne               Fredericton
# ...
